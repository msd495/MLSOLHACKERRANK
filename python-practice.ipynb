# %%
for i in range(5):
    print (i)
    if(i>2):
        print("greater than 2")
    else:a
        print("less than 2")
# Out:
# 0
# less than 2
# 1
# less than 2
# 2
# less than 2
# 3
# greater than 2
# 4
# greater than 2

# %%
import scipy 
print('scipy: {}'.format(scipy.__version__))
import numpy 
print('numpy: {}'.format(numpy.__version__))
# Out:
# scipy: 0.19.1
# numpy: 1.13.1

# %%
import sklearn
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# sklearn: 0.19.0

# %%
data="hello world"
print(data[0])
print(len(data))
print(data)
# Out:
# h
# 11
# hello world

# %%
# Multiple Assignment
a, b, c = 1, 2, 3
print(a, b, c)
# Out:
# 1 2 3

# %%
#data structure in python.
#tuples---->Read only collections of items
a = (1, 2, 3)
print (a)
# Out:
# (1, 2, 3)

# %%
#list
mylist = [1, 2, 3]
print(mylist[0])
mylist.append(4)
print("List Length", len(mylist))
for value in mylist:
    print (value)
# Out:
# 1
# List Length 4
# 1
# 2
# 3
# 4

# %%
#dictionary
mydict = {'a': 1, 'b': 2, 'c': 3}
for i in mydict:
    print(mydict[i])

print("All the keys are ",mydict.keys())
print("All the values are ",mydict.values())
# Out:
# 1
# 2
# 3
# All the keys are  dict_keys(['a', 'b', 'c'])
# All the values are  dict_values([1, 2, 3])

# %%
import numpy
mylist = [1, 2, 3]
myarray = numpy.array(mylist)
print(myarray)
print(myarray.shape)
# Out:
# [1 2 3]
# (3,)

# %%
import numpy
mylist = [[1, 2, 3], [3, 4, 5]]
myarray = numpy.array(mylist)
print(myarray)
print(myarray.shape)
print(myarray[0])
print(myarray[-1])
# Out:
# [[1 2 3]
#  [3 4 5]]
# (2, 3)
# [1 2 3]
# [3 4 5]

# %%
# arithmetic
import numpy
myarray1 = numpy.array([2, 2, 2])
myarray2 = numpy.array([3, 3, 3])
print("Addition is :",(myarray1 + myarray2))
print("Multiplication: ",(myarray1 * myarray2))
# Out:
# Addition is : [5 5 5]
# Multiplication:  [6 6 6]

# %%
import matplotlib.pyplot as plt
import numpy
myarray = numpy.array([1, 2, 3])
plt.plot(myarray)
plt.xlabel('some x axis')
plt.ylabel('some y axis')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy
x = numpy.array([1, 2, 3])
y = numpy.array([2, 4, 6])
plt.scatter(x,y)
plt.xlabel('some x axis')
plt.ylabel('some y axis')
plt.show()
